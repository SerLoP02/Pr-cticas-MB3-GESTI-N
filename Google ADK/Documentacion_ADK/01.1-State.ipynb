# %% [markdown]
# https://adk.dev/sessions/state/

# %% [markdown]
# En Google ADK se define un estado como "the state attribute acts like the agent's dedicated scratchpad for that specific interaction. While session.events holds the full history, session.state is where the agent stores and updates dynamic details needed during the conversation"

# %%
initial_state = {
    "user:name": "Arthas", # Este par es compartido por todas las sessiones con el mismo user_id (dentro de la misma aplicación)
    "Prefereces": "Programming" # Esto solo vive en la sesión actual
}

# %% [markdown]
# Para usarlo, se manda como argumento al crear la sesión (en create_session())
